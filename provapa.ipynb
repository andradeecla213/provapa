# %% [markdown]
# <a href="https://colab.research.google.com/github/andradeecla213/provapa/blob/main/provapa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada definir se é menor de idade, adulto ou idoso

idade = int( input("Digite sua idade: ") )

if idade <= 17:
  print (f"Você é menor de idade")

elif idade <= 59:
  print (f" Você é adulto")

else:
  print (f" Você é idoso")
# Out:
# Digite sua idade: 12
# Você é menor de idade

# %%
#Desconto

#Comando
Preço = float (input ("Digite o preço: "))


desconto1 = 10
calculo1 = Preço * (desconto1/100)
calculo_1 = Preço - calculo1

desconto2 = 20
calculo2 = Preço * (desconto2/100)
calculo_2 = Preço - calculo2

if Preço <=100:
 print(f"Sem desconto")

elif valor >= 101 and valor <= 500:
  print(f"você possui 10% de desconto. Valor final é de: R${calculo1_1} ")

else:
  print(f"você possui 20% de desconto. Valor final é de: R${calculo2_1}")
# Out:
# Digite o preço: 333
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2150/2806442812.py in <cell line: 0>()
#      16  print(f"Sem desconto")
#      17
# ---> 18 elif valor >= 101 and valor <= 500:
#      19   print(f"você possui 10% de desconto. Valor final é de: R${calculo1_1} ")
#      20
#
# NameError: name 'valor' is not defined
